# %% [markdown]
# # LinkedIn Zip Playground
#
# Import the `Zip` object to solve the games bellow.

# %%
from linkedin_games import Zip

# %% [markdown]
# ## Zip No. [166](https://puzznest.com/linkedin-games/zip-166-answer)
#
# August 30<sup>th</sup>, 2025
#
# <div align='center'>
#     <img src='../assets/zip-166.png' alt='Zip No. 166' width='30%'>
# </div>

# %%
zip_game = Zip(
    size=6,
    numbered_squares=[
        (6,5), (6,6), (5,6), (6,4), (5,3), (4,2), (3,1), (2,1),
        (1,1), (1,2), (1,3), (3,5), (2,4), (3,4), (4,3), (4,6)
    ]
)
zip_game.solve()
zip_game.show()

# %% [markdown]
# Solution of Zip No. [166](https://puzznest.com/linkedin-games/zip-166-answer).
#
# <div align='center'>
#     <img src='../assets/zip-166-solution.png' alt='Solution of Zip No. 166' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Zip No. [264](https://puzznest.com/linkedin-games/zip-264-answer)
#
# December 6<sup>th</sup>, 2025
#
# <div align='center'>
#     <img src='../assets/zip-264.png' alt='Zip No. 264' width='30%'>
# </div>

# %%
zip_game = Zip(
    size=8,
    numbered_squares=[
        (3,5), (4,5), (2,4), (3,7), (4,7), (5,7), (6,2), (7,7), (6,7), (6,4),
        (6,3), (4,3), (4,2), (5,2), (2,2), (2,3), (3,4), (4,4), (5,5), (5,6)
    ]
)
zip_game.solve()
zip_game.show()

# %% [markdown]
# Solution of Zip No. [264](https://puzznest.com/linkedin-games/zip-264-answer).
#
# <div align='center'>
#     <img src='../assets/zip-264-solution.png' alt='Solution of Zip No. 264' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Zip No. [271](https://puzznest.com/linkedin-games/zip-271-answer)
#
# December 13<sup>th</sup>, 2025
#
# <div align='center'>
#     <img src='../assets/zip-271.png' alt='Zip No. 271' width='30%'>
# </div>

# %%
zip_game = Zip(
    size=7,
    numbered_squares=[
        (2,6), (2,4), (2,2), (3,3), (5,2), (3,4), (3,5), (5,6), (5,4), (6,3), (6,5), (6,4)
    ],
    walls=[
        ((2,2), (3,2)), ((2,4), (3,4)), ((2,6), (3,6)), ((3,3), (4,3)), ((3,5), (4,5)),
        ((5,2), (6,2)), ((5,4), (6,4)), ((5,6), (6,6)), ((6,3), (7,3)), ((6,5), (7,5))
    ]
)
zip_game.solve()
zip_game.show()

# %% [markdown]
# Solution of Zip No. [271](https://puzznest.com/linkedin-games/zip-271-answer).
#
# <div align='center'>
#     <img src='../assets/zip-271-solution.png' alt='Solution of Zip No. 271' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Zip No. [501](https://puzznest.com/linkedin-games/zip-501-answer)
#
# July 31<sup>st</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/zip-501.png' alt='Zip No. 501' width='30%'>
# </div>

# %%
zip_game = Zip(
    size=7,
    numbered_squares=[(2,4), (5,2), (2,6), (1,7), (6,4), (3,6), (7,1), (6,2)],
    walls=[
        ((1,2), (2,2)), ((1,3), (2,3)), ((2,1), (2,2)), ((2,4), (2,5)),
        ((3,1), (3,2)), ((3,4), (3,5)), ((3,3), (4,3)), ((3,4), (4,4)),
        ((4,4), (5,4)), ((4,5), (5,5)), ((5,3), (5,4)), ((5,6), (5,7)),
        ((6,3), (6,4)), ((6,6), (6,7)), ((6,5), (7,5)), ((6,6), (7,6))
    ]
)
zip_game.solve()
zip_game.show()

# %% [markdown]
# Solution of Zip No. [501](https://puzznest.com/linkedin-games/zip-501-answer).
#
# <div align='center'>
#     <img src='../assets/zip-501-solution.png' alt='Solution of Zip No. 501' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Zip No. [506](https://puzznest.com/linkedin-games/zip-506-answer)
#
# August 8<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/zip-506.png' alt='Zip No. 506' width='30%'>
# </div>

# %%
zip_game = Zip(
    board_dims=(6,6),
    numbered_squares=[(1,3), (1,4), (6,4), (3,5), (4,4), (4,2), (5,2), (6,3), (3,3), (2,5)]
)
zip_game.solve()
zip_game.show()

# %% [markdown]
# Solution of Zip No. [506](https://puzznest.com/linkedin-games/zip-506-answer).
#
# <div align='center'>
#     <img src='../assets/zip-506-solution.png' alt='Solution of Zip No. 506' width='30%'>
# </div>
#
# ---
