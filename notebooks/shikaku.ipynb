# %% [markdown]
# # Shikaku Playground
#
# Import the `Shikaku` object to solve the games bellow.

# %%
from linkedin_games.shikaku import Shikaku

# %% [markdown]
# ## Easy Shikaku
#
# August 10<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-10-easy.png' alt='Easy Shikaku 2026-08-10' width='30%'>
#     <p>Source: <a href="https://shikakuofthe.day/easy/260810">Shikaku of the Day</a></p>
# </div>

# %%
seeds = {
    (1,5): 1,
    (2,3): 6, (2,4): 2,
    (3,2): 1, (3,4): 2,
    (4,1): 3, (4,2): 2,
    (5,4): 4, (5,5): 4
}
shikaku = Shikaku(5, seeds)
shikaku.solve(verbose=True)
shikaku.show()
# Out:
# Shikaku game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (2, 3), 'top_left': (1, 1)},
#  {'dims': (2, 1), 'top_left': (1, 4)},
#  {'dims': (1, 1), 'top_left': (1, 5)},
#  {'dims': (4, 1), 'top_left': (2, 5)},
#  {'dims': (3, 1), 'top_left': (3, 1)},
#  {'dims': (1, 1), 'top_left': (3, 2)},
#  {'dims': (1, 2), 'top_left': (3, 3)},
#  {'dims': (2, 1), 'top_left': (4, 2)},
#  {'dims': (2, 2), 'top_left': (4, 3)}]

# %% [markdown]
# Solution of Easy Shikaku
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-10-easy-solution.png' alt='Solution of Easy Shikaku 2026-08-10' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Medium Shikaku
#
# August 11<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-11-medium.png' alt='Medium Shikaku 2026-08-11' width='30%'>
#     <p>Source: <a href="https://shikakuofthe.day/medium/260811">Shikaku of the Day</a></p>
# </div>

# %%
seeds = {
    (2, 1):  2, (2, 4): 16,
    (3, 4): 14, (3, 8):  3, (3,10): 3,
    (4, 9):  6, (4,10):  1,
    (5, 2):  5, (5, 7):  2,
    (6, 1):  4, (6, 8):  1,
    (7, 7):  3,
    (8, 6):  3, (8, 8):  2, (8,10): 6,
    (9, 1):  6, (9, 4): 15, (9, 8): 2,
    (10,6):  4, (10,8):  2,
}
shikaku = Shikaku(10, seeds)
shikaku.solve(verbose=True)
shikaku.show()
# Out:
# Shikaku game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (2, 1), 'top_left': (1, 1)},
#  {'dims': (2, 8), 'top_left': (1, 2)},
#  {'dims': (3, 1), 'top_left': (1, 10)},
#  {'dims': (2, 7), 'top_left': (3, 1)},
#  {'dims': (3, 1), 'top_left': (3, 8)},
#  {'dims': (6, 1), 'top_left': (3, 9)},
#  {'dims': (1, 1), 'top_left': (4, 10)},
#  {'dims': (1, 5), 'top_left': (5, 1)},
#  {'dims': (1, 2), 'top_left': (5, 6)},
#  {'dims': (6, 1), 'top_left': (5, 10)},
#  {'dims': (2, 2), 'top_left': (6, 1)},
#  {'dims': (5, 3), 'top_left': (6, 3)},
#  {'dims': (3, 1), 'top_left': (6, 6)},
#  {'dims': (3, 1), 'top_left': (6, 7)},
#  {'dims': (1, 1), 'top_left': (6, 8)},
#  {'dims': (2, 1), 'top_left': (7, 8)},
#  {'dims': (3, 2), 'top_left': (8, 1)},
#  {'dims': (2, 2), 'top_left': (9, 6)},
#  {'dims': (1, 2), 'top_left': (9, 8)},
#  {'dims': (1, 2), 'top_left': (10, 8)}]

# %% [markdown]
# Solution of Medium Shikaku.
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-11-medium-solution.png' alt='Solution of Medium Shikaku 2026-08-11' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Hard Shikaku
#
# August 12<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-12-hard.png' alt='Hard Shikaku 2026-08-12' width='40%'>
#     <p>Source: <a href="https://shikakuofthe.day/hard/260812">Shikaku of the Day</a></p>
# </div>

# %%
seeds = {
    ( 1, 2):  8, ( 1, 8): 15,
    ( 2, 3): 11, ( 2, 9):  4, ( 2,18): 15,
    ( 3, 4):  8, ( 3,13): 10,
    ( 4, 5):  6, ( 4, 9):  4, ( 4,16):  5,
    ( 5,16):  4,
    ( 6, 2):  6, ( 6,10):  8, ( 6,13):  5,
    ( 7,15):  8, ( 7,17):  2, ( 7,20):  3,
    ( 8, 7): 24, ( 8, 9):  3, ( 8,12):  6,
    (10, 4):  2, (10, 7):  2, (10, 8):  2, (10,14): 15, (10,15): 4, (10,16):  2, (10,20): 30,
    (11, 5):  5, (11, 6):  3, (11, 7):  1, (11,11): 16, (11,17): 10,
    (12, 4):  3, (12, 5):  1, (12, 7):  2, (12, 8):  3, (12, 9):  6, 
    (13, 5):  2, (13,12):  5, (13,13):  4, (13,16):  2,
    (14, 3):  7, (14,13):  2, (14,15):  8,
    (15, 8):  9, (15,10):  8,
    (16, 5):  2,
    (17, 1): 26, (17, 8):  9,
    (18, 4):  5,
    (19, 4):  4, (19,12): 27, (19,19): 18,
}
shikaku = Shikaku(20, seeds)
shikaku.solve(verbose=True)
shikaku.show()
# Out:
# Shikaku game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (4, 2), 'top_left': (1, 1)},
#  {'dims': (11, 1), 'top_left': (1, 3)},
#  {'dims': (8, 1), 'top_left': (1, 4)},
#  {'dims': (6, 1), 'top_left': (1, 5)},
#  {'dims': (1, 15), 'top_left': (1, 6)},
#  {'dims': (8, 3), 'top_left': (2, 6)},
#  {'dims': (1, 4), 'top_left': (2, 9)},
#  {'dims': (2, 5), 'top_left': (2, 13)},
#  {'dims': (5, 3), 'top_left': (2, 18)},
#  {'dims': (4, 1), 'top_left': (3, 9)},
#  {'dims': (4, 2), 'top_left': (3, 10)},
#  {'dims': (6, 1), 'top_left': (3, 12)},
#  {'dims': (1, 5), 'top_left': (4, 13)},
#  {'dims': (3, 2), 'top_left': (5, 1)},
#  {'dims': (5, 1), 'top_left': (5, 13)},
#  {'dims': (1, 4), 'top_left': (5, 14)},
#  {'dims': (15, 1), 'top_left': (6, 14)},
#  {'dims': (4, 2), 'top_left': (6, 15)},
#  {'dims': (2, 1), 'top_left': (6, 17)},
#  {'dims': (5, 1), 'top_left': (7, 5)},
#  {'dims': (3, 1), 'top_left': (7, 9)},
#  {'dims': (8, 2), 'top_left': (7, 10)},
# ...

# %% [markdown]
# Solution of Hard Shikaku.
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-12-hard-solution.png' alt='Solution of Hard Shikaku 2026-08-12' width='40%'>
# </div>
#
# ---

# %% [markdown]
# ## Expert Shikaku
#
# August 13<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-13-expert.png' alt='Expert Shikaku 2026-08-13' width='40%'>
#     <p>Source: <a href="https://shikakuofthe.day/expert/260813">Shikaku of the Day</a></p>
# </div>

# %%
seeds = {
    ( 1,29): 14,
    ( 3,10): 52, ( 3,24): 32,
    ( 5,10): 22, ( 5,15): 45, ( 5,20): 27,
    ( 7, 5):  7,
    ( 8, 5): 18,
    ( 9,12): 48,
    (11, 6):  2, (11, 9):  4, (11,19):  5, (11,25): 18, (11,26): 11, (11,29): 38,
    (13, 8):  6, (13,14): 45, (13,27):  6, (13,28): 21,
    (14, 6):  2, (14, 7): 34,
    (15, 9):  1, (15,19):  2,
    (16, 5): 18, (16,20): 14, (16,23): 34,
    (17,19):  8,
    (18, 6):  5, (18, 9): 10, (18,27): 7,
    (19,10):  7, (19,21):  4,
    (20, 5):  2, (20, 6):  1, (20,13): 14, (20,23):  5, (20,24):  1,
    (21,21):  2, (21,22):  6, (21,24):  3,
    (22, 1): 42, (22,10):  2, (22,13):  2, (22,16):  3, (22,17):  8, (22,19):  2, (22,25):  5, (22,26):  1, (22,30):  1, 
    (23, 3): 23, (23,21):  1, (23,23):  1, (23,29):  2, (23,30):  5,
    (24,19): 30, (24,20):  5, (24,26):  2, (24,27):  3,
    (26,27): 15,
    (28, 2):  6, (28,21): 28, (28,30): 18,
    (29, 1):  2, (29, 4): 30, (29,10): 60,
    (30, 2):  2,
}
shikaku = Shikaku(30, seeds)
shikaku.solve(verbose=True)
shikaku.show()
# Out:
# result.Solver.status: ok
# Shikaku game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (4, 13), 'top_left': (1, 1)},
#  {'dims': (9, 5), 'top_left': (1, 14)},
#  {'dims': (9, 3), 'top_left': (1, 19)},
#  {'dims': (17, 2), 'top_left': (1, 22)},
#  {'dims': (2, 7), 'top_left': (1, 24)},
#  {'dims': (8, 4), 'top_left': (3, 24)},
#  {'dims': (21, 1), 'top_left': (3, 28)},
#  {'dims': (19, 2), 'top_left': (3, 29)},
#  {'dims': (21, 2), 'top_left': (5, 1)},
#  {'dims': (2, 11), 'top_left': (5, 3)},
#  {'dims': (1, 7), 'top_left': (7, 3)},
#  {'dims': (12, 4), 'top_left': (7, 10)},
#  {'dims': (23, 1), 'top_left': (8, 3)},
#  {'dims': (3, 6), 'top_left': (8, 4)},
#  {'dims': (9, 5), 'top_left': (10, 14)},
#  {'dims': (5, 1), 'top_left': (10, 19)},
#  {'dims': (7, 2), 'top_left': (10, 20)},
#  {'dims': (9, 2), 'top_left': (11, 4)},
#  {'dims': (2, 1), 'top_left': (11, 6)},
#  {'dims': (3, 2), 'top_left': (11, 7)},
#  {'dims': (4, 1), 'top_left': (11, 9)},
# ...

# %% [markdown]
# Solution of Expert Shikaku.
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-13-expert-solution.png' alt='Solution of Expert Shikaku' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Master Shikaku
#
# August 14<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-14-master.png' alt='Master Shikaku 2026-08-14' width='50%'>
#     <p>Source: <a href="https://shikakuofthe.day/master/260814">Shikaku of the Day</a></p>
# </div>

# %%
seeds = {
    ( 1,13): 80,
    ( 4,32): 72,
    ( 5,15): 34,
    ( 7,22): 56, ( 7,39): 52,
    ( 8,36): 12,
    ( 9, 3): 60, ( 9,27): 38,
    (10,29): 14, (10,35): 26,
    (11,17):  3, (11,21):  3, (11,22): 12,
    (12,11):  6, (12,14):  6, (12,24):  3, (12,26):  3,
    (13,30): 55,
    (14, 2): 48, (14,14):  4, (14,18): 84, (14,21):  8,
    (15,12): 12, (15,26):  2,
    (16, 6):  8, (16,13):  6, (16,33):  6,
    (17, 5):  8, (17,11):  2, (17,15):  7, (17,20):  7, (17,22):  2,
    (18, 6):  2, (18, 8):  3, (18,23):  7, (18,30):  8,
    (19, 3):  5, (19,13):  3, (19,14):  2, (19,20):  1, (19,22):  2, (19,40): 10,
    (20, 1): 24, (20,11):  4, (20,21): 39, (20,30):  2, (20,37): 10,
    (21,15):  2, (21,29):  1, (21,33): 24, (21,37):  1, (21,40):  3,
    (22, 2):105, (22, 8):  3, (22,30): 10, (22,37):  2, (22,39):  4,
    (23,12):  4, (23,14): 17, (23,15):  3, (23,36):  8, (23,38):  2,
    (24, 8):  3, (24,10): 32, (24,26): 12, (24,29):  4, (24,34): 10,
    (25,23): 12, (25,38): 24,
    (26, 7): 13, (26,25): 20, (26,28): 25,
    (27, 8):  4, (27,13):  8, (27,34):  5, (27,36):  5,
    (28,10):  8, (28,11): 12, (28,24): 27,
    (30,26):  3,
    (33,13):  5, (33,15): 12, (33,20): 28, (33,27):110,
    (34, 8): 66, (34,13):  3,
    (36,36): 55,
    (38,19): 44,
}
shikaku = Shikaku(40, seeds)
shikaku.solve(verbose=True)
shikaku.show()
# Out:
# result.Solver.status: ok
# Shikaku game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (2, 40), 'top_left': (1, 1)},
#  {'dims': (2, 36), 'top_left': (3, 1)},
#  {'dims': (13, 4), 'top_left': (3, 37)},
#  {'dims': (5, 12), 'top_left': (5, 1)},
#  {'dims': (2, 17), 'top_left': (5, 13)},
#  {'dims': (11, 5), 'top_left': (5, 30)},
#  {'dims': (26, 1), 'top_left': (5, 35)},
#  {'dims': (12, 1), 'top_left': (5, 36)},
#  {'dims': (4, 14), 'top_left': (7, 13)},
#  {'dims': (19, 2), 'top_left': (7, 27)},
#  {'dims': (14, 1), 'top_left': (7, 29)},
#  {'dims': (6, 8), 'top_left': (10, 1)},
#  {'dims': (16, 2), 'top_left': (10, 9)},
#  {'dims': (6, 1), 'top_left': (10, 11)},
#  {'dims': (12, 1), 'top_left': (10, 12)},
#  {'dims': (2, 3), 'top_left': (11, 13)},
#  {'dims': (1, 3), 'top_left': (11, 16)},
#  {'dims': (1, 3), 'top_left': (11, 19)},
#  {'dims': (6, 2), 'top_left': (11, 22)},
#  {'dims': (3, 1), 'top_left': (11, 24)},
# ...

# %% [markdown]
# Solution of Master Shikaku.
#
# <div align='center'>
#     <img src='../assets/shikaku-of-the-day-2026-08-14-master-solution.png' alt='Solution of Master Shikaku 2026-08-14' width='50%'>
# </div>
#
# ---
