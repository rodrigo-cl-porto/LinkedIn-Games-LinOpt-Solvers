# %% [markdown]
# # LinkedIn Mini Sudoku Playground
#
# Import the `Mini Sudoku` object to solve the games bellow.

# %%
from linkedin_games import MiniSudoku

# %% [markdown]
# ## Mini Sudoku No. [60](https://puzznest.com/linkedin-games/mini-sudoku-60-answer)
#
# October 10<sup>th</sup>, 2025
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-60.png' alt='Mini Sudoku No. 60' width='30%'>
# </div>

# %%
mini_sudoku = MiniSudoku({
    (1,1): 1, (2,2): 2, (2,5): 3, (3,3): 3, (3,4): 6,
    (4,3): 5, (4,4): 4, (5,2): 4, (5,5): 5, (6,6): 6
})
mini_sudoku.solve()
mini_sudoku.show()

# %% [markdown]
# Solution of Mini Sudoku No. [60](https://puzznest.com/linkedin-games/mini-sudoku-60-answer).
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-60-solution.png' alt='Solution of Mini Sudoku No. 60' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Mini Sudoku No. [104](https://puzznest.com/linkedin-games/mini-sudoku-104-answer)
#
# November 23<sup>rd</sup>, 2025
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-104.png' alt='Mini Sudoku No. 104' width='30%'>
# </div>

# %%
mini_sudoku = MiniSudoku({
    (2,1): 5, (2,6): 1, (3,2): 3, (3,5): 2, (4,3): 1,
    (4,4): 4, (5,3): 2, (5,4): 5, (6,3): 3, (6,4): 6,
})
mini_sudoku.solve()
mini_sudoku.show()

# %% [markdown]
# Solution of Mini Sudoku No. [104](https://puzznest.com/linkedin-games/mini-sudoku-104-answer).
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-104-solution.png' alt='Solution of Mini Sudoku No. 104' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Mini Sudoku No. [197](https://puzznest.com/linkedin-games/mini-sudoku-197-answer)
#
# February 24<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-197.png' alt='Mini Sudoku No. 197' width='30%'>
# </div>

# %%
mini_sudoku = MiniSudoku({
    (1,4): 1, (1,5): 2, (2,2): 2, (2,3): 1, (2,5): 3,
    (3,2): 5, (3,6): 6, (4,1): 3, (4,5): 5, (4,6): 1,
    (5,1): 2, (5,2): 1, (5,4): 4, (6,3): 6, (6,4): 5,
})
mini_sudoku.solve()
mini_sudoku.show()

# %% [markdown]
# Solution of Mini Sudoku No. [197](https://puzznest.com/linkedin-games/mini-sudoku-197-answer).
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-197-solution.png' alt='Solution of Mini Sudoku No. 197' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Mini Sudoku No. [228](https://puzznest.com/linkedin-games/mini-sudoku-228-answer)
#
# March 27<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-228.png' alt='Mini Sudoku No. 228' width='30%'>
# </div>

# %%
mini_sudoku = MiniSudoku({
    (1,1): 1, (1,5): 2, (2,3): 6, (2,6): 4, (3,2): 2,
    (4,5): 5, (5,1): 3, (5,4): 5, (6,2): 4, (6,6): 6,
})
mini_sudoku.solve()
mini_sudoku.show()

# %% [markdown]
# Solution of Mini Sudoku No. [228](https://puzznest.com/linkedin-games/mini-sudoku-228-answer).
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-228-solution.png' alt='Solution of Mini Sudoku No. 228' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Mini Sudoku No. [359](https://puzznest.com/linkedin-games/mini-sudoku-359-answer)
#
# August 5<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-359.png' alt='Mini Sudoku No. 359' width='30%'>
# </div>

# %%
mini_sudoku = MiniSudoku({
    (1,1): 1, (1,3): 2, (2,4): 5, (3,1): 2, (3,5): 1,
    (4,2): 3, (4,6): 4, (5,3): 4, (6,4): 3, (6,6): 2
})
mini_sudoku.solve()
mini_sudoku.show()

# %% [markdown]
# Solution of Mini Sudoku No. [359](https://puzznest.com/linkedin-games/mini-sudoku-359-answer)
#
# <div align='center'>
#     <img src='./assets/mini-sudoku-359-solution.png' alt='Solution of Mini Sudoku No. 359' width='30%'>
# </div>
#
# ---
