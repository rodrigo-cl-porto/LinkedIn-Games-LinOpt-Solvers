# %%
from linkedin_games import MiniSudoku

# %% [markdown]
# Mini Sudoku No. 60

# %%
filled_squares = {
    (1,1): 1,
    (2,2): 2,
    (2,5): 3,
    (3,3): 3,
    (3,4): 6,
    (4,3): 5,
    (4,4): 4,
    (5,2): 4,
    (5,5): 5,
    (6,6): 6
}
mini_sudoku = MiniSudoku(filled_squares)
mini_sudoku.solve(verbose=True)
mini_sudoku.show()

# %% [markdown]
# Mini Sudoku No. 359 (2025/08/05)

# %%
filled_squares = {
    (1,1): 1,
    (1,3): 2,
    (2,4): 5,
    (3,1): 2,
    (3,5): 1,
    (4,2): 3,
    (4,6): 4,
    (5,3): 4,
    (6,4): 3,
    (6,6): 2
}
mini_sudoku = MiniSudoku(filled_squares)
mini_sudoku.solve(verbose=True)
mini_sudoku.show()
