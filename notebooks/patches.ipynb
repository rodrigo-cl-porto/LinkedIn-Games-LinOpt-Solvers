# %% [markdown]
# # LinkedIn Patches Playground
#
# Import the `Patches` object to solve the games bellow.

# %%
from linkedin_games import Patches

# %% [markdown]
# ## Patches No. [16](https://puzznest.com/linkedin-games/patches-16-answer)
#
# April 2<sup>nd</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/patches-16.png' alt='Patches No. 16' width='30%'>
# </div>

# %%
seeds = {
    (1,2): {"color": "#846A0B", "area": 2},
    (1,4): {"color": "#096B78", "area": 6},
    (2,6): {"color": "#5A3DB1", "area": 2},
    (3,1): {"color": "#0A7541", "area": 6},
    (3,3): {"color": "#EF6C00", "area": 2, "shape":"vertical"},
    (4,4): {"color": "#E30102", "area": 4, "shape":"square"},
    (4,6): {"color": "#097BB1", "area": 2},
    (5,1): {"color": "#A01E4E", "area": 2},
    (6,3): {"color": "#9B3C1C", "area": 6},
    (6,5): {"color": "#503B36", "area": 4},
}
patches = Patches(6, seeds)
patches.solve()
patches.show()
# Out:
# Patches game solved successfully!

# %% [markdown]
# Solution of Patches No. [16](https://puzznest.com/linkedin-games/patches-16-answer).
#
# <div align='center'>
#     <img src='../assets/patches-16-solution.png' alt='Solution of Patches No. 16' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Patches No. [46](https://puzznest.com/linkedin-games/patches-46-answer)
#
# May 2<sup>nd</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/patches-46.png' alt='Patches No. 46' width='30%'>
# </div>

# %%
seeds = {
    (1,5): {"shape": "horizontal"},
    (2,3): {"shape": "horizontal"},
    (3,1): {"area": 8},
    (3,6): {"area": 10},
    (5,2): {"area": 3},
    (5,7): {"area": 14},
    (6,5): {"shape": "vertical"},
    (7,3): {"shape": "square"},
}
patches = Patches(8, seeds)
patches.solve(verbose=True)
patches.show()
# Out:
# Patches game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (8, 1), 'top_left': (1, 1)},
#  {'dims': (1, 7), 'top_left': (1, 2)},
#  {'dims': (1, 5), 'top_left': (2, 2)},
#  {'dims': (7, 2), 'top_left': (2, 7)},
#  {'dims': (2, 5), 'top_left': (3, 2)},
#  {'dims': (1, 3), 'top_left': (5, 2)},
#  {'dims': (4, 2), 'top_left': (5, 5)},
#  {'dims': (3, 3), 'top_left': (6, 2)}]

# %% [markdown]
# Solution of Patches No. [46](https://puzznest.com/linkedin-games/patches-46-answer).
#
# <div align='center'>
#     <img src='../assets/patches-46-solution.png' alt='Solution of Patches No. 46' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Patches No. [94](https://puzznest.com/linkedin-games/patches-94-answer)
#
# June 19<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/patches-94.png' alt='Patches No. 94' width='30%'>
# </div>

# %%
seeds = {
    (1,1): {"area": 5},
    (1,8): {"area": 3},
    (2,2): {"area": 3},
    (2,7): {"area": 5},
    (3,4): None,
    (3,5): None,
    (4,2): {"area": 3},
    (4,7): {"area": 3},
    (5,2): {"area": 4},
    (5,7): {"area": 6},
    (6,4): None,
    (6,5): None,
    (7,2): {"area": 8},
    (7,7): {"area": 4},
    (8,1): {"area": 6},
    (8,8): {"area": 2},
}
patches = Patches(8, seeds)
patches.solve(verbose=True)
patches.show()
# Out:
# Patches game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (1, 5), 'top_left': (1, 1)},
#  {'dims': (1, 3), 'top_left': (1, 6)},
#  {'dims': (1, 3), 'top_left': (2, 1)},
#  {'dims': (1, 5), 'top_left': (2, 4)},
#  {'dims': (6, 1), 'top_left': (3, 1)},
#  {'dims': (1, 3), 'top_left': (3, 2)},
#  {'dims': (1, 4), 'top_left': (3, 5)},
#  {'dims': (1, 3), 'top_left': (4, 2)},
#  {'dims': (3, 1), 'top_left': (4, 5)},
#  {'dims': (1, 3), 'top_left': (4, 6)},
#  {'dims': (2, 2), 'top_left': (5, 2)},
#  {'dims': (2, 1), 'top_left': (5, 4)},
#  {'dims': (2, 3), 'top_left': (5, 6)},
#  {'dims': (2, 4), 'top_left': (7, 2)},
#  {'dims': (2, 2), 'top_left': (7, 6)},
#  {'dims': (2, 1), 'top_left': (7, 8)}]

# %% [markdown]
# Solution of Patches No. [94](https://puzznest.com/linkedin-games/patches-94-answer).
#
# <div align='center'>
#     <img src='../assets/patches-94-solution.png' alt='Solution of Patches No. 94' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Patches No. [121](https://puzznest.com/linkedin-games/patches-121-answer)
#
# July 16<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/patches-121.png' alt='Patches No. 121' width='30%'>
# </div>

# %%
seeds = {
    (1,1): {"color": "#846A0B", "area": 8},
    (2,5): {"color": "#0A7541", "area": 8},
    (3,3): {"color": "#5A3DB1"},
    (4,4): {"color": "#EF6C00"},
    (5,2): {"color": "#096B78", "area": 8},
    (6,6): {"color": "#E30102", "area": 6, "shape": "vertical"},
}
patches = Patches(6, seeds)
patches.solve(verbose=True)
patches.show()
# Out:
# Patches game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (4, 2), 'top_left': (1, 1)},
#  {'dims': (2, 4), 'top_left': (1, 3)},
#  {'dims': (1, 4), 'top_left': (3, 3)},
#  {'dims': (1, 2), 'top_left': (4, 3)},
#  {'dims': (3, 2), 'top_left': (4, 5)},
#  {'dims': (2, 4), 'top_left': (5, 1)}]

# %% [markdown]
# Solution of Patches No. [121](https://puzznest.com/linkedin-games/patches-121-answer).
#
# <div align='center'>
#     <img src='../assets/patches-121-solution.png' alt='Solution of Patches No. 121' width='30%'>
# </div>
#
# ---

# %% [markdown]
# ## Patches No. [141](https://puzznest.com/linkedin-games/patches-141-answer)
#
# August 5<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='../assets/patches-141.png' alt='Patches No. 141' width='30%'>
# </div>

# %%
seeds = {
    (1,7): {"shape": "square"},
    (3,3): {"area": 15},
    (6,6): {"area": 25},
    (8,2): {"shape": "vertical"},
}
patches = Patches(8, seeds)
patches.solve(verbose=True)
patches.show()
# Out:
# Patches game solved successfully!
# These are the rectagles that solves the game:
# [{'dims': (3, 5), 'top_left': (1, 1)},
#  {'dims': (3, 3), 'top_left': (1, 6)},
#  {'dims': (5, 3), 'top_left': (4, 1)},
#  {'dims': (5, 5), 'top_left': (4, 4)}]

# %% [markdown]
# Solution of Patches No. [141](https://puzznest.com/linkedin-games/patches-141-answer).
#
# <div align='center'>
#     <img src='../assets/patches-141-solution.png' alt='Solution of Patches No. 141' width='30%'>
# </div>
#
# ---
