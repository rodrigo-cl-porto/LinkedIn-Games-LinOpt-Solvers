# %% [markdown]
# # Sudoku Playground
#
# Import the `Sudoku` object to solve the games bellow.

# %%
from linkedin_games.sudoku import Sudoku

# %% [markdown]
# ## Beginner Sudoku
#
# August 3<sup>rd</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-03-beginner.png' alt='Beginner Sudoku (2026-08-03)' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-03/beginner">Sudoku of the Day</a></p>
# </div>

# %%
sudoku = Sudoku({
    (1,3): 9, (1,4): 6, (1,5): 8, (1,6): 4, (1,7): 7,
    (2,2): 6, (2,3): 2, (2,4): 3, (2,6): 1, (2,9): 8,
    (3,1): 8, (3,4): 7, (3,5): 9, (3,8): 1,
    (4,1): 2, (4,3): 6, (4,4): 8, (4,5): 3, (4,6): 9, 
    (5,5): 4,
    (6,4): 1, (6,5): 2, (6,6): 7, (6,7): 5, (6,9): 6,
    (7,2): 7, (7,5): 6, (7,6): 8, (7,9): 4,
    (8,1): 6, (8,4): 9, (8,6): 3, (8,7): 8, (8,8): 7,
    (9,3): 8, (9,4): 4, (9,5): 7, (9,6): 5, (9,7): 2,
})
sudoku.solve()
sudoku.show()

# %% [markdown]
# Solution of Beginner Sudoku
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-03-beginner-solution.png' alt='Solution of Beginner Sudoku' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-03/beginner/solution">Sudoku of the Day</a></p>
# </div>
#
# ---

# %% [markdown]
# ## Easy Sudoku
#
# August 4<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-04-easy.png' alt='Easy Sudoku (2026-08-04)' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-04/easy">Sudoku of the Day</a></p>
# </div>

# %%
sudoku = Sudoku({
    (1,3): 4, (1,5): 2,
    (2,1): 5, (2,6): 6, (2,8): 4,
    (3,1): 6, (3,2): 7, (3,7): 9, (3,8): 2, (3,9): 8,
    (4,1): 2, (4,2): 6, (4,4): 8, (4,6): 5,
    (5,4): 7, (5,5): 9, (5,6): 1,
    (6,4): 2, (6,6): 4, (6,8): 8, (6,9): 5,
    (7,1): 8, (7,2): 9, (7,3): 3, (7,8): 6, (7,9): 1,
    (8,2): 4, (8,4): 3, (8,9): 2,
    (9,5): 1, (9,7): 3
})
sudoku.solve()
sudoku.show()

# %% [markdown]
# Solution of Easy Sudoku
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-04-easy-solution.png' alt='Solution of Easy Sudoku' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-04/easy/solution">Sudoku of the Day</a></p>
# </div>
#
# ---

# %% [markdown]
# ## Medium Sudoku
#
# August 5<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-05-medium.png' alt='Medium Sudoku (2026-08-05)' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-05/medium">Sudoku of the Day</a></p>
# </div>

# %%
sudoku = Sudoku({
    (1,3): 7, (1,5): 9, (1,9): 6,
    (2,8): 7, (2,9): 2,
    (3,4): 8, (3,6): 6, (3,8): 5,
    (4,1): 7, (4,5): 5, (4,8): 4,
    (5,2): 4, (5,4): 1, (5,6): 9, (5,8): 6,
    (6,2): 3, (6,5): 2, (6,9): 8,
    (7,2): 7, (7,4): 2, (7,6): 1,
    (8,1): 5, (8,2): 2,
    (9,1): 8, (9,5): 4, (9,7): 9,
})
sudoku.solve()
sudoku.show()

# %% [markdown]
# Solution of Medium Sudoku
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-05-medium-solution.png' alt='Solution of Medium Sudoku' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-05/medium/solution">Sudoku of the Day</a></p>
# </div>
#
# ---

# %% [markdown]
# ## Tricky Sudoku
#
# August 6<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-06-tricky.png' alt='Tricky Sudoku (2026-08-06)' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-06/tricky">Sudoku of the Day</a></p>
# </div>

# %%
sudoku = Sudoku({
    (1,3): 7, (1,4): 2, (1,6): 1,
    (2,1): 1, (2,2): 4, (2,8): 2,
    (3,5): 9, (3,7): 6, (3,9): 5,
    (4,1): 4, (4,2): 1, (4,6): 9,
    (5,3): 9, (5,5): 6, (5,7): 1,
    (6,4): 3, (6,8): 9, (6,9): 4,
    (7,1): 6, (7,3): 3, (7,5): 4,
    (8,2): 8, (8,8): 6, (8,9): 2,
    (9,4): 5, (9,6): 6, (9,7): 4,
})
sudoku.solve()
sudoku.show()

# %% [markdown]
# Solution of Tricky Sudoku
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-06-tricky-solution.png' alt='Solution of Tricky Sudoku' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-06/tricky/solution">Sudoku of the Day</a></p>
# </div>
#
# ---

# %% [markdown]
# ## Fiendish Sudoku
#
# August 7<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-07-fiendish.png' alt='Fiendish Sudoku (2026-08-07)' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-07/fiendish">Sudoku of the Day</a></p>
# </div>

# %%
sudoku = Sudoku({
    (1,5): 8, (1,6): 3, (1,8): 9,
    (2,4): 7, (2,7): 4,
    (3,2): 7, (3,3): 8, (3,8): 1,
    (4,4): 3, (4,9): 6,
    (5,3): 4, (5,5): 6, (5,7): 3,
    (6,1): 1, (6,6): 5,
    (7,2): 4, (7,7): 7, (7,8): 2,
    (8,3): 2, (8,6): 8,
    (9,2): 5, (9,4): 6, (9,5): 3,
})
sudoku.solve()
sudoku.show()

# %% [markdown]
# Solution of Fiendish Sudoku
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-07-fiendish-solution.png' alt='Solution of Fiendish Sudoku' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-07/fiendish/solution">Sudoku of the Day</a></p>
# </div>
#
# ---

# %% [markdown]
# ## Diabolical Sudoku
#
# August 8<sup>th</sup>, 2026
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-08-diabolical.png' alt='Diabolical Sudoku (2026-08-08)' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-08/diabolical">Sudoku of the Day</a></p>
# </div>

# %%
sudoku = Sudoku({
    (1,7): 9, (1,8): 3,
    (2,3): 5, (2,4): 6, (2,6): 3, (2,8): 7, (2,9): 4,
    (3,5): 4, (3,8): 8,
    (4,2): 5, (4,4): 4, (4,6): 7, (4,7): 8,
    (5,1): 7, (5,9): 6,
    (6,3): 1, (6,4): 3, (6,6): 9, (6,8): 5,
    (7,2): 6, (7,5): 9,
    (8,1): 9, (8,2): 4, (8,4): 1, (8,6): 5, (8,7): 7,
    (9,2): 7, (9,3): 3,
})
sudoku.solve()
sudoku.show()

# %% [markdown]
# Solution of Diabolical Sudoku
#
# <div align='center'>
#     <img src='./assets/sudoku-2026-08-08-diabolical-solution.png' alt='Solution of Diabolical Sudoku' width='30%'>
#     <p>Source: <a href="https://www.sudokuoftheday.com/dailypuzzles/2026-08-08/diabolical/solution">Sudoku of the Day</a></p>
# </div>
#
# ---
